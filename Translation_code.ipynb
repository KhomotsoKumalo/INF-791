# %%
# !pip install googletrans

# %%
import pandas as pd
from deep_translator import GoogleTranslator

# Define a function to translate based on word type (nature)
def translate_with_nature(french_word, nature):
    if not french_word:
        return "Error: Empty input"

    # Return the word directly based on its nature
    # No additional contextual phrases are added
    text_to_translate = french_word

    try:
        # Translate the word in context
        translation = GoogleTranslator(source='fr', target='en').translate(text_to_translate)
        return translation  # Return the full translation
    except Exception as e:
        print(f"Exception: {str(e)} for word: {french_word}")
        return f"Error: {str(e)}"

# Load the Excel file
input_path = 'C:\\Users\\khomo\\data_tshikama_xls-1 (1).xlsx'
df = pd.read_excel(input_path)

# Check if 'FRANCAIS' and 'NATURE' columns exist
if 'FRANCAIS' in df.columns and 'NATURE' in df.columns:
    # Translate only the first 50 rows of the specified columns considering their nature
    df.loc[:3001, 'ENGLISH_TEMP'] = df.loc[:3001].apply(
        lambda row: translate_with_nature(row['FRANCAIS'], row['NATURE']), axis=1
    )
    
    # Insert the 'ENGLISH' column next to the 'FRANCAIS' column
    col_index = df.columns.get_loc('FRANCAIS')
    df.insert(col_index + 1, 'ENGLISH', df.pop('ENGLISH_TEMP'))
else:
    print("Error: 'FRANCAIS' or 'NATURE' column not found in DataFrame")

# Save the updated DataFrame to a new Excel file (only for the test)
output_path = 'C:\\Users\\khomo\\lexicon_translation_test.xlsx'
df.to_excel(output_path, index=False)

print(f"Translation completed and saved to {output_path}")
# Out:
# Exception: nan --> text must be a valid text with maximum 5000 character,otherwise it cannot be translated for word: nan
# Translation completed and saved to C:\Users\khomo\lexicon_translation_test.xlsx

# %%
import pandas as pd
from deep_translator import GoogleTranslator

# Define a function to translate from English to other languages
def translate_english_to_other_languages(english_word, target_language):
    if not english_word:
        return "Error: Empty input"
    try:
        translation = GoogleTranslator(source='en', target=target_language).translate(english_word)
        return translation  # Return the full translation to the target language
    except Exception as e:
        print(f"Exception: {str(e)} for word: {english_word}")
        return f"Error: {str(e)}"

# Load the Excel file containing English translations
input_path = 'C:\\Users\\khomo\\lexicon_translation_test.xlsx'
df = pd.read_excel(input_path)

# Check if the 'ENGLISH' column exists
if 'ENGLISH' in df.columns:
    # Specify target languages for translation
    target_languages = {
        'Sesotho': 'st',  # Sesotho
        'Sepedi': 'nso',   # Sepedi
        'Afrikaans': 'af',  # Afrikaans
        'Xhosa': 'xh',     # Xhosa
        'Zulu': 'zu'       # Zulu
    }

    # Translate English to other languages and add as new columns
    for lang_name, lang_code in target_languages.items():
        print(f"Translating to {lang_name}...")
        df[lang_name] = df['ENGLISH'].apply(lambda x: translate_english_to_other_languages(x, lang_code))
        print(f"Translation to {lang_name} completed.")

else:
    print("Error: 'ENGLISH' column not found in DataFrame")

# Save the updated DataFrame to a new Excel file
output_path = 'C:\\Users\\khomo\\lexicon_all_languages.xlsx'
df.to_excel(output_path, index=False)

print(f"All translations completed and saved to {output_path}")
# Out:
# Translating to Sesotho...
# Translation to Sesotho completed.
# Translating to Sepedi...
# Exception: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)) for word: Herbs
# Exception: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')) for word: repeated
# Translation to Sepedi completed.
# Translating to Afrikaans...
# Translation to Afrikaans completed.
# Translating to Xhosa...
# Translation to Xhosa completed.
# Translating to Zulu...
# Exception: Request exception can happen due to an api connection error. Please check your connection and try again for word: leave
# Translation to Zulu completed.
# All translations completed and saved to C:\Users\khomo\lexicon_all_languages.xlsx

# %%
import pandas as pd
import random

# Load the previously translated DataFrame
input_path = 'C:\\Users\\khomo\\lexicon_all_languages.xlsx'
df = pd.read_excel(input_path)

# Separate words by sentiment
positive_words = df[df['SENTIMENT'] == 'Positif']['ENGLISH'].dropna().tolist()
negative_words = df[df['SENTIMENT'] == 'Negatif']['ENGLISH'].dropna().tolist()
neutral_words = df[df['SENTIMENT'] == 'Neutre']['ENGLISH'].dropna().tolist()

# Set the number of sentences to generate for each sentiment
num_sentences_per_sentiment = 10
sentences = []

# Function to generate sentences for a given sentiment
def generate_sentences(word_list, sentiment_label):
    for _ in range(num_sentences_per_sentiment):
        # Randomly select sentence length between 2 and 10
        sentence_length = random.randint(2, 10)

        # Check if there are enough words in the list to sample
        if len(word_list) >= sentence_length:
            sentence = ' '.join(random.sample(word_list, sentence_length))
        else:
            # If not enough words, use as many as possible
            sentence = ' '.join(word_list)

        # Capitalize the first word and add a period at the end
        sentences.append(f"{sentence.capitalize()}. (Sentiment: {sentiment_label})")

# Generate sentences for each sentiment type
if positive_words:
    generate_sentences(positive_words, 'Positif')
else:
    print("No positive words found.")

if negative_words:
    generate_sentences(negative_words, 'Negatif')
else:
    print("No negative words found.")

if neutral_words:
    generate_sentences(neutral_words, 'Neutre')
else:
    print("No neutral words found.")

# Save sentences to a new text file
output_path = 'C:\\Users\\khomo\\generated_sentences.txt'
with open(output_path, 'w') as f:
    for sentence in sentences:
        f.write(sentence + '\n')

print(f"{num_sentences_per_sentiment * 3} sentences generated and saved to {output_path}.")
# Out:
# 30 sentences generated and saved to C:\Users\khomo\generated_sentences.txt.

# %%
import pandas as pd
import random

# Load the dataset
file_path = 'C:\\Users\\khomo\\lexicon_all_languages.xlsx'  # Update with your file path
df = pd.read_excel(file_path)

# Ensure the DataFrame contains necessary columns
expected_columns = ['CILUBA', 'ENGLISH', 'FRANCAIS', 'Sesotho', 'Sepedi', 'Afrikaans', 'Xhosa', 'Zulu', 'SCORE', 'SENTIMENT']
missing_columns = [col for col in expected_columns if col not in df.columns]

if missing_columns:
    raise ValueError(f"The dataset is missing the following columns: {', '.join(missing_columns)}")

# Create translation lexicon and scoring dictionary from the dataset
translation_lexique = dict(zip(df['ENGLISH'].str.lower(), 
                               df[['CILUBA', 'FRANCAIS', 'Sesotho', 'Sepedi', 'Afrikaans', 'Xhosa', 'Zulu']].fillna('').apply(lambda x: x.tolist(), axis=1)))
score_lexique = dict(zip(df['ENGLISH'].str.lower(), df['SCORE']))  # English to score

def translate_text_using_lexicon(text, translation_lexique):
    words = text.lower().split()  # Split input text into words
    translations = {lang: [] for lang in ['CILUBA', 'FRANCAIS', 'Sesotho', 'Sepedi', 'Afrikaans', 'Xhosa', 'Zulu']}  # Create a dict for translations
    scores = []  # To hold scores for each word
    translated_indices = set()  # Keep track of which words have been translated

    # Start checking from longest possible phrases to the individual words
    for start in range(len(words)):
        if start in translated_indices:  # Skip if the word has already been translated
            continue
        
        for end in range(start + 1, len(words) + 1):
            phrase = ' '.join(words[start:end])  # Create the phrase from words[start:end]
            if phrase in translation_lexique:
                translated_words = translation_lexique[phrase]  # Get the translations for the whole phrase
                for i, lang in enumerate(translations.keys()):
                    translations[lang].append(translated_words[i] if i < len(translated_words) else '')  # Handle missing translations
                scores.append(score_lexique.get(phrase, 0))  # Get score for the whole phrase
                translated_indices.update(range(start, end))  # Mark all involved indices as translated
                break  # Stop checking once we find a translation for this phrase
        else:
            # If no translation was found for any phrases starting from this word, check the single word
            single_word = words[start]
            if start not in translated_indices:  # Check only if not already translated
                translated_words = translation_lexique.get(single_word, [''] * len(translations))  # Get translations for the single word
                for i, lang in enumerate(translations.keys()):
                    translations[lang].append(translated_words[i] if i < len(translated_words) else '')  # Handle missing translations
                scores.append(score_lexique.get(single_word, 0))  # Get score for the word

    return translations, scores  # Return a dict of translated sentences for each language and scores

def analyse_sentiment(translated_words, scores):
    total_score = sum(scores)  # Sum of all scores

    # Determine sentiment based on total score
    if total_score > 0.5:
        sentiment = "Positive"
    elif total_score < -0.5:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    word_scores = {word: score for word, score in zip(translated_words, scores)}

    return total_score, sentiment, word_scores  # Return total score, sentiment, and individual word scores

# Generate 50 random sentences
input_path = 'C:\\Users\\khomo\\lexicon_translation_test.xlsx'
df_english = pd.read_excel(input_path)
words = df_english['ENGLISH'].dropna().tolist()
num_sentences = 50
sentences = [' '.join(random.sample(words, random.randint(5, 12))).capitalize() + '.' for _ in range(num_sentences)]

# Process each sentence for translation and sentiment analysis
for i, english_text in enumerate(sentences, 1):
    print(f"Processing sentence {i}: '{english_text}'")
    
    # Translate the text using the lexicon
    translations, scores = translate_text_using_lexicon(english_text, translation_lexique)

    # Create a dictionary to hold sentiment analysis results for each language
    sentiment_results = {}

    # Analyze sentiment for each translated language
    for lang, translated_words in translations.items():
        total_score, sentiment, word_scores = analyse_sentiment(translated_words, scores)
        sentiment_results[lang] = {
            "translated_sentence": ' '.join(translated_words),  # Join translated words into a single string
            "total_score": total_score,
            "sentiment": sentiment,
            "word_scores": word_scores
        }

    # Display results for each language with separation
    print(f"\nOriginal English Sentence: '{english_text}'\n")
    for lang, result in sentiment_results.items():
        print(f"Translated Sentence ({lang}):", result['translated_sentence'])  # Display the joined sentence
        print(f"Total Score ({lang}):", result['total_score'])  # Display the total score
        print(f"Sentiment ({lang}):", result['sentiment'])  # Display the overall sentiment
        print(f"Word Scores ({lang}):", result['word_scores'])  # Display individual word scores
        print("\n" + "-" * 50 + "\n")  # Separator between languages
# Out:
# Processing sentence 1: 'Fog fifty-four space sixty two ask 59shirt plate listen eyelash heine sin transport.'
#
# Original English Sentence: 'Fog fifty-four space sixty two ask 59shirt plate listen eyelash heine sin transport.'
#
# Translated Sentence (CILUBA): ditshima makumiatanu-inayi ditekemena makumiasambombo ibidi kulomba  Dilongo Kunvua Lukofi lukinu Mibi
# Total Score (CILUBA): 16
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'ditshima': 3, 'makumiatanu-inayi': 0, 'ditekemena': 1, 'makumiasambombo': 0, 'ibidi': 0, 'kulomba': 4, '': 0, 'Dilongo': 1, 'Kunvua': 1, 'Lukofi': 3, 'lukinu': 1, 'Mibi': 2}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Brouillard cinquante-quatre esparance soixante deux Demander  Assiette ecouter Cil heine Pécher
# Total Score (FRANCAIS): 16
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Brouillard': 3, 'cinquante-quatre': 0, 'esparance': 1, 'soixante': 0, 'deux': 0, 'Demander': 4, '': 0, 'Assiette': 1, 'ecouter': 1, 'Cil': 3, 'heine': 1, 'Pécher': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Moholi mashome a mahlano a metso e mene sebaka mashome a tsheletseng pedi Botsa  Letlapa mamela Eyelashe heine Sebe
# Total Score (Sesotho): 16
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Moholi': 3, 'mashome a mahlano a metso e mene': 0, 'sebaka': 1, 'mashome a tsheletseng': 0, 'pedi': 0, 'Botsa': 4, '': 0, 'Letlapa': 1, 'mamela': 1, 'Eyelashe': 3, 'heine': 1, 'Sebe': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Kgodi masomehlano-nne sekgoba masometshela pedi Kgopela  Poleiti theeletša Eyelash ya mahlo heine Sebe
# Total Score (Sepedi): 16
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Kgodi': 3, 'masomehlano-nne': 0, 'sekgoba': 1, 'masometshela': 0, 'pedi': 0, 'Kgopela': 4, '': 0, 'Poleiti': 1, 'theeletša': 1, 'Eyelash ya mahlo': 3, 'heine': 1, 'Sebe': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Mis vier-en-vyftig spasie sestig twee Vra  Plaat luister Wimper heine Sonde
# Total Score (Afrikaans): 16
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Mis': 3, 'vier-en-vyftig': 0, 'spasie': 1, 'sestig': 0, 'twee': 0, 'Vra': 4, '': 0, 'Plaat': 1, 'luister': 1, 'Wimper': 3, 'heine': 1, 'Sonde': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Inkungu amashumi amahlanu anesine indawo Amashumi amathandathu Mbini Buza  Ipleyiti mamela Ukhophe hayi Isono
# Total Score (Xhosa): 16
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Inkungu': 3, 'amashumi amahlanu anesine': 0, 'indawo': 1, 'Amashumi amathandathu': 0, 'Mbini': 0, 'Buza': 4, '': 0, 'Ipleyiti': 1, 'mamela': 1, 'Ukhophe': 3, 'hayi': 1, 'Isono': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Inkungu amashumi amahlanu nane isikhala amashumi ayisithupha ezimbili Buza  Ipuleti lalela Inkophe hayi Isono
# Total Score (Zulu): 16
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Inkungu': 3, 'amashumi amahlanu nane': 0, 'isikhala': 1, 'amashumi ayisithupha': 0, 'ezimbili': 0, 'Buza': 4, '': 0, 'Ipuleti': 1, 'lalela': 1, 'Inkophe': 3, 'hayi': 1, 'Isono': 2}
#
# --------------------------------------------------
#
# Processing sentence 2: 'Solution tarpaulin sleep request tooth road hope.'
#
# Original English Sentence: 'Solution tarpaulin sleep request tooth road hope.'
#
# Translated Sentence (CILUBA): bipeta Nteta Lala lomba Dino njila
# Total Score (CILUBA): 17
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'bipeta': 4, 'Nteta': 3, 'Lala': 4, 'lomba': 1, 'Dino': 1, 'njila': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): solution Bâche Dors demande Dent route
# Total Score (FRANCAIS): 17
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'solution': 4, 'Bâche': 3, 'Dors': 4, 'demande': 1, 'Dent': 1, 'route': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): tharollo Tarpaulin Robala kopo Leino tsela
# Total Score (Sesotho): 17
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'tharollo': 4, 'Tarpaulin': 3, 'Robala': 4, 'kopo': 1, 'Leino': 1, 'tsela': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): tharollo Tarpaulin ya go dira dilo Robala kgopelo Leino tsela
# Total Score (Sepedi): 17
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'tharollo': 4, 'Tarpaulin ya go dira dilo': 3, 'Robala': 4, 'kgopelo': 1, 'Leino': 1, 'tsela': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): oplossing Seil Slaap versoek Tand pad
# Total Score (Afrikaans): 17
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'oplossing': 4, 'Seil': 3, 'Slaap': 4, 'versoek': 1, 'Tand': 1, 'pad': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): isisombululo Iseyile Lala isicelo Izinyo indlela
# Total Score (Xhosa): 17
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'isisombululo': 4, 'Iseyile': 3, 'Lala': 4, 'isicelo': 1, 'Izinyo': 1, 'indlela': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): isisombululo Iseyili Lala isicelo Izinyo umgwaqo
# Total Score (Zulu): 17
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'isisombululo': 4, 'Iseyili': 3, 'Lala': 4, 'isicelo': 1, 'Izinyo': 1, 'umgwaqo': 4, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 3: 'Play were mouth number to pour out fetish announce saliva.'
#
# Original English Sentence: 'Play were mouth number to pour out fetish announce saliva.'
#
# Translated Sentence (CILUBA): kunaya  Mukana bunyi Kupumuna Manga luabila
# Total Score (CILUBA): 8
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'kunaya': 1, '': 0, 'Mukana': 3, 'bunyi': 1, 'Kupumuna': 2, 'Manga': -1, 'luabila': 2}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Jouer etaient Bouche nombre epancher Fétiche Annoncer
# Total Score (FRANCAIS): 8
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Jouer': 1, 'etaient': 0, 'Bouche': 3, 'nombre': 1, 'epancher': 2, 'Fétiche': -1, 'Annoncer': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Bapala ba ne ba Molomo palo ho tshollela Fetish Phatlalatsa
# Total Score (Sesotho): 8
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Bapala': 1, 'ba ne ba': 0, 'Molomo': 3, 'palo': 1, 'ho tshollela': 2, 'Fetish': -1, 'Phatlalatsa': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Raloka be e le Molomo nomoro go tšhollela Fetish ya fetish Tsebiša
# Total Score (Sepedi): 8
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Raloka': 1, 'be e le': 0, 'Molomo': 3, 'nomoro': 1, 'go tšhollela': 2, 'Fetish ya fetish': -1, 'Tsebiša': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Speel was Mond nommer uit te gooi Fetisj Kondig aan
# Total Score (Afrikaans): 8
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Speel': 1, 'was': 0, 'Mond': 3, 'nommer': 1, 'uit te gooi': 2, 'Fetisj': -1, 'Kondig aan': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Dlala babe Umlomo inani ukuphalaza Fetish Yazisa
# Total Score (Xhosa): 8
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Dlala': 1, 'babe': 0, 'Umlomo': 3, 'inani': 1, 'ukuphalaza': 2, 'Fetish': -1, 'Yazisa': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Dlala babe Umlomo inombolo ukuthulula I-Fetish Memezela
# Total Score (Zulu): 8
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Dlala': 1, 'babe': 0, 'Umlomo': 3, 'inombolo': 1, 'ukuthulula': 2, 'I-Fetish': -1, 'Memezela': 2, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 4: 'Advancement lip dust waves mountain all 31give unfaithful back advantage.'
#
# Original English Sentence: 'Advancement lip dust waves mountain all 31give unfaithful back advantage.'
#
# Translated Sentence (CILUBA): Didiundisha Mushiku lupuishi mavuala Mukuna   kayilulamatu nyima
# Total Score (CILUBA): 4
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Didiundisha': 4, 'Mushiku': 6, 'lupuishi': -4, 'mavuala': -1, 'Mukuna': 3, '': 0, 'kayilulamatu': -5, 'nyima': 1}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): avancement Lèvre Poussière Vagues Montagne tous  Infidèle Dos
# Total Score (FRANCAIS): 4
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'avancement': 4, 'Lèvre': 6, 'Poussière': -4, 'Vagues': -1, 'Montagne': 3, 'tous': 0, '': 0, 'Infidèle': -5, 'Dos': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): tswelopele Molomo Lerole Maqhubu Thaba Tsohle  ya sa tshepaleng Morao
# Total Score (Sesotho): 4
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'tswelopele': 4, 'Molomo': 6, 'Lerole': -4, 'Maqhubu': -1, 'Thaba': 3, 'Tsohle': 0, '': 0, 'ya sa tshepaleng': -5, 'Morao': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): tšwelopele Molomo Lerole Maphoto a Thaba Ka moka  Ba sa botegego Morago
# Total Score (Sepedi): 4
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'tšwelopele': 4, 'Molomo': 6, 'Lerole': -4, 'Maphoto a': -1, 'Thaba': 3, 'Ka moka': 0, '': 0, 'Ba sa botegego': -5, 'Morago': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): vooruitgang Lip Stof Golwe Berg Almal  Ontrou Terug
# Total Score (Afrikaans): 4
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'vooruitgang': 4, 'Lip': 6, 'Stof': -4, 'Golwe': -1, 'Berg': 3, 'Almal': 0, '': 0, 'Ontrou': -5, 'Terug': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): ukuqhubela phambili Umlebe Uthuli Amaza Intaba Konke  Ukungathembeki Emva
# Total Score (Xhosa): 4
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'ukuqhubela phambili': 4, 'Umlebe': 6, 'Uthuli': -4, 'Amaza': -1, 'Intaba': 3, 'Konke': 0, '': 0, 'Ukungathembeki': -5, 'Emva': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): intuthuko Izindebe Uthuli Amagagasi Intaba Konke  Ongathembekile Emuva
# Total Score (Zulu): 4
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'intuthuko': 4, 'Izindebe': 6, 'Uthuli': -4, 'Amagagasi': -1, 'Intaba': 3, 'Konke': 0, '': 0, 'Ongathembekile': -5, 'Emuva': 1}
#
# --------------------------------------------------
#
# Processing sentence 5: 'Consolation vein seal engineer duck sweat.'
#
# Original English Sentence: 'Consolation vein seal engineer duck sweat.'
#
# Translated Sentence (CILUBA): kusamba mujilu mbumba Magnimela mpatu
# Total Score (CILUBA): 17
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'kusamba': 5, 'mujilu': 2, 'mbumba': 5, 'Magnimela': 2, 'mpatu': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Consolation Veine sceau Ingénieur canard
# Total Score (FRANCAIS): 17
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Consolation': 5, 'Veine': 2, 'sceau': 5, 'Ingénieur': 2, 'canard': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): matshediso Mothapo tiiso Moenjiniere letata
# Total Score (Sesotho): 17
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'matshediso': 5, 'Mothapo': 2, 'tiiso': 5, 'Moenjiniere': 2, 'letata': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Khomotšo Mothapo tswalela Moentšineere lepelepele
# Total Score (Sepedi): 17
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Khomotšo': 5, 'Mothapo': 2, 'tswalela': 5, 'Moentšineere': 2, 'lepelepele': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Troos Aar seël Ingenieur eend
# Total Score (Afrikaans): 17
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Troos': 5, 'Aar': 2, 'seël': 5, 'Ingenieur': 2, 'eend': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Intuthuzelo Umthambo itywina Injineli idada
# Total Score (Xhosa): 17
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Intuthuzelo': 5, 'Umthambo': 2, 'itywina': 5, 'Injineli': 2, 'idada': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Induduzo Umthambo uphawu Unjiniyela idada
# Total Score (Zulu): 17
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Induduzo': 5, 'Umthambo': 2, 'uphawu': 5, 'Unjiniyela': 2, 'idada': 3, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 6: 'Neck bush you have hate brain to nause hit speed.'
#
# Original English Sentence: 'Neck bush you have hate brain to nause hit speed.'
#
# Translated Sentence (CILUBA): nshingu Tshikutu wewa  kukina Bongo miengu kututa
# Total Score (CILUBA): 3
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'nshingu': 2, 'Tshikutu': 4, 'wewa': 0, '': 0, 'kukina': -7, 'Bongo': 3, 'miengu': -1, 'kututa': 2}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Cou buisson toi  Haïr Cerveau nauser frapper
# Total Score (FRANCAIS): 3
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Cou': 2, 'buisson': 4, 'toi': 0, '': 0, 'Haïr': -7, 'Cerveau': 3, 'nauser': -1, 'frapper': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Molala sehlahla Wena  Lehloyo Boko ho nyekeloa ke pelo otla
# Total Score (Sesotho): 3
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Molala': 2, 'sehlahla': 4, 'Wena': 0, '': 0, 'Lehloyo': -7, 'Boko': 3, 'ho nyekeloa ke pelo': -1, 'otla': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Molala sethokgwa Wena  Hloya Bjoko go nyema moko betha
# Total Score (Sepedi): 3
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Molala': 2, 'sethokgwa': 4, 'Wena': 0, '': 0, 'Hloya': -7, 'Bjoko': 3, 'go nyema moko': -1, 'betha': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Nek bossie Jy  Haat Brein om te naar tref
# Total Score (Afrikaans): 3
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Nek': 2, 'bossie': 4, 'Jy': 0, '': 0, 'Haat': -7, 'Brein': 3, 'om te naar': -1, 'tref': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Intamo ityholo Wena  Intiyo Ubuchopho ukuba nesicaphucaphu hit
# Total Score (Xhosa): 3
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Intamo': 2, 'ityholo': 4, 'Wena': 0, '': 0, 'Intiyo': -7, 'Ubuchopho': 3, 'ukuba nesicaphucaphu': -1, 'hit': 2}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Intamo ihlathi Wena  Inzondo Ubuchopho ukucanuzela kwenhliziyo hit
# Total Score (Zulu): 3
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Intamo': 2, 'ihlathi': 4, 'Wena': 0, '': 0, 'Inzondo': -7, 'Ubuchopho': 3, 'ukucanuzela kwenhliziyo': -1, 'hit': 2}
#
# --------------------------------------------------
#
# Processing sentence 7: 'Blood hold to nause ruminate give birth 88realize beginning.'
#
# Original English Sentence: 'Blood hold to nause ruminate give birth 88realize beginning.'
#
# Translated Sentence (CILUBA): Mashi Kukuata miengu kudilulula kupesha
# Total Score (CILUBA): 7
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Mashi': 3, 'Kukuata': 1, 'miengu': -1, 'kudilulula': 2, 'kupesha': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Sang tenir nauser ruminer donner
# Total Score (FRANCAIS): 7
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Sang': 3, 'tenir': 1, 'nauser': -1, 'ruminer': 2, 'donner': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): madi tshoarela ho nyekeloa ke pelo ruminate fa
# Total Score (Sesotho): 7
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'madi': 3, 'tshoarela': 1, 'ho nyekeloa ke pelo': -1, 'ruminate': 2, 'fa': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Madi swara go nyema moko ruminate ya go ruminate fa
# Total Score (Sepedi): 7
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Madi': 3, 'swara': 1, 'go nyema moko': -1, 'ruminate ya go ruminate': 2, 'fa': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Bloed hou om te naar herkou gee
# Total Score (Afrikaans): 7
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Bloed': 3, 'hou': 1, 'om te naar': -1, 'herkou': 2, 'gee': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Igazi bamba ukuba nesicaphucaphu i-ruminate nika
# Total Score (Xhosa): 7
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Igazi': 3, 'bamba': 1, 'ukuba nesicaphucaphu': -1, 'i-ruminate': 2, 'nika': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Igazi bamba ukucanuzela kwenhliziyo ruminate nika
# Total Score (Zulu): 7
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Igazi': 3, 'bamba': 1, 'ukucanuzela kwenhliziyo': -1, 'ruminate': 2, 'nika': 2, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 8: 'Die to write sing rip bush hazard worship.'
#
# Original English Sentence: 'Die to write sing rip bush hazard worship.'
#
# Translated Sentence (CILUBA): kufua Funda kuimba kupanda Tshikutu Njiwu
# Total Score (CILUBA): 1
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'kufua': -9, 'Funda': 3, 'kuimba': 2, 'kupanda': -3, 'Tshikutu': 4, 'Njiwu': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): mourir écrire Chanter dechirer buisson Danger
# Total Score (FRANCAIS): 1
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'mourir': -9, 'écrire': 3, 'Chanter': 2, 'dechirer': -3, 'buisson': 4, 'Danger': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): shwa ho ngola Opelang kgaola sehlahla Kotsi
# Total Score (Sesotho): 1
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'shwa': -9, 'ho ngola': 3, 'Opelang': 2, 'kgaola': -3, 'sehlahla': 4, 'Kotsi': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): hlokofala go ngwala Opela gagola sethokgwa Kotsi
# Total Score (Sepedi): 1
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'hlokofala': -9, 'go ngwala': 3, 'Opela': 2, 'gagola': -3, 'sethokgwa': 4, 'Kotsi': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): sterf te skryf Sing skeur bossie Gevaar
# Total Score (Afrikaans): 1
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'sterf': -9, 'te skryf': 3, 'Sing': 2, 'skeur': -3, 'bossie': 4, 'Gevaar': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): fa ukubhala Cula Lala kakuhle ityholo Ingozi
# Total Score (Xhosa): 1
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'fa': -9, 'ukubhala': 3, 'Cula': 2, 'Lala kakuhle': -3, 'ityholo': 4, 'Ingozi': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): fa ukubhala Hlabelelani rip ihlathi Ingozi
# Total Score (Zulu): 1
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'fa': -9, 'ukubhala': 3, 'Hlabelelani': 2, 'rip': -3, 'ihlathi': 4, 'Ingozi': 4, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 9: 'Chew give behavior cradle ankle face pants machete soul.'
#
# Original English Sentence: 'Chew give behavior cradle ankle face pants machete soul.'
#
# Translated Sentence (CILUBA): kutshiankunya kupesha Ciskadilu Kalalu Kampombe tshimfuanyi muhanu Muela
# Total Score (CILUBA): 21
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'kutshiankunya': 2, 'kupesha': 2, 'Ciskadilu': 1, 'Kalalu': 3, 'Kampombe': 5, 'tshimfuanyi': 2, 'muhanu': 3, 'Muela': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): mâcher donner Comportement berceau Cheville Visage Pantalon Machette
# Total Score (FRANCAIS): 21
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'mâcher': 2, 'donner': 2, 'Comportement': 1, 'berceau': 3, 'Cheville': 5, 'Visage': 2, 'Pantalon': 3, 'Machette': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): hlafuna fa Boitshwaro cradle Leqaqailane Sefahleho Borikhoe Machete
# Total Score (Sesotho): 21
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'hlafuna': 2, 'fa': 2, 'Boitshwaro': 1, 'cradle': 3, 'Leqaqailane': 5, 'Sefahleho': 2, 'Borikhoe': 3, 'Machete': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): sohla fa Maitshwaro lesaka Kokoilane Sefahlogo Marokgwana Machete ya go swana le ya
# Total Score (Sepedi): 21
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'sohla': 2, 'fa': 2, 'Maitshwaro': 1, 'lesaka': 3, 'Kokoilane': 5, 'Sefahlogo': 2, 'Marokgwana': 3, 'Machete ya go swana le ya': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): kou gee Gedrag wieg Enkel Gesig Broek Machete
# Total Score (Afrikaans): 21
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'kou': 2, 'gee': 2, 'Gedrag': 1, 'wieg': 3, 'Enkel': 5, 'Gesig': 2, 'Broek': 3, 'Machete': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): hlafuna nika Ukuziphatha imbeleko Iqakala Ubuso Iibhulukhwe I-Machete
# Total Score (Xhosa): 21
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'hlafuna': 2, 'nika': 2, 'Ukuziphatha': 1, 'imbeleko': 3, 'Iqakala': 5, 'Ubuso': 2, 'Iibhulukhwe': 3, 'I-Machete': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): hlafuna nika Ukuziphatha imbeleko Iqakala Ubuso Amabhulukwe I-Machete
# Total Score (Zulu): 21
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'hlafuna': 2, 'nika': 2, 'Ukuziphatha': 1, 'imbeleko': 3, 'Iqakala': 5, 'Ubuso': 2, 'Amabhulukwe': 3, 'I-Machete': 3, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 10: 'Cupboard embassy cause free i justification breast wealth duck.'
#
# Original English Sentence: 'Cupboard embassy cause free i justification breast wealth duck.'
#
# Translated Sentence (CILUBA): kabadi Bulopo Ikila kupikula Ndi dibingishibua dibele bubanji
# Total Score (CILUBA): 23
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'kabadi': 4, 'Bulopo': 3, 'Ikila': 3, 'kupikula': 4, 'Ndi': 0, 'dibingishibua': 5, 'dibele': 3, 'bubanji': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Armoire ambassade causer Affranchir je Justification Sein richesse
# Total Score (FRANCAIS): 23
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Armoire': 4, 'ambassade': 3, 'causer': 3, 'Affranchir': 4, 'je': 0, 'Justification': 5, 'Sein': 3, 'richesse': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Khaboto boemeli sesosa Mahala ke Tokafatso Letswele leruo
# Total Score (Sesotho): 23
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Khaboto': 4, 'boemeli': 3, 'sesosa': 3, 'Mahala': 4, 'ke': 0, 'Tokafatso': 5, 'Letswele': 3, 'leruo': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Khatepote ntlo ya botseta hlola Lokologile nna Go lokafatšwa Letswele lehumo
# Total Score (Sepedi): 23
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Khatepote': 4, 'ntlo ya botseta': 3, 'hlola': 3, 'Lokologile': 4, 'nna': 0, 'Go lokafatšwa': 5, 'Letswele': 3, 'lehumo': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Kas ambassade oorsaak Gratis ek Regverdiging Bors rykdom
# Total Score (Afrikaans): 23
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Kas': 4, 'ambassade': 3, 'oorsaak': 3, 'Gratis': 4, 'ek': 0, 'Regverdiging': 5, 'Bors': 3, 'rykdom': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Ikhabhathi indlu yozakuzo unobangela Mahala mina Uthethelelo Ibele ubutyebi
# Total Score (Xhosa): 23
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Ikhabhathi': 4, 'indlu yozakuzo': 3, 'unobangela': 3, 'Mahala': 4, 'mina': 0, 'Uthethelelo': 5, 'Ibele': 3, 'ubutyebi': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Ikhabethe inxusa imbangela Mahhala mna Ukulungisiswa Isifuba ingcebo
# Total Score (Zulu): 23
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Ikhabethe': 4, 'inxusa': 3, 'imbangela': 3, 'Mahhala': 4, 'mna': 0, 'Ukulungisiswa': 5, 'Isifuba': 3, 'ingcebo': 1, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 11: 'Lion flee to walk bible engineer cord intelligence.'
#
# Original English Sentence: 'Lion flee to walk bible engineer cord intelligence.'
#
# Translated Sentence (CILUBA): NtaMbua kunyema kuenda mukandawanzambi Magnimela Lombola
# Total Score (CILUBA): 16
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'NtaMbua': 3, 'kunyema': 1, 'kuenda': 2, 'mukandawanzambi': 3, 'Magnimela': 2, 'Lombola': 5, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): lion Fuir marcher bible Ingénieur Cordonne
# Total Score (FRANCAIS): 16
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'lion': 3, 'Fuir': 1, 'marcher': 2, 'bible': 3, 'Ingénieur': 2, 'Cordonne': 5, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): tau Balehang ho tsamaya Bibele Moenjiniere Kgoele
# Total Score (Sesotho): 16
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'tau': 3, 'Balehang': 1, 'ho tsamaya': 2, 'Bibele': 3, 'Moenjiniere': 2, 'Kgoele': 5, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): tau Ngwega go sepela Beibele Moentšineere Thapo ya go swara
# Total Score (Sepedi): 16
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'tau': 3, 'Ngwega': 1, 'go sepela': 2, 'Beibele': 3, 'Moentšineere': 2, 'Thapo ya go swara': 5, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): leeu Vlug te loop Bybel Ingenieur Koord
# Total Score (Afrikaans): 16
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'leeu': 3, 'Vlug': 1, 'te loop': 2, 'Bybel': 3, 'Ingenieur': 2, 'Koord': 5, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): ingonyama Balekani ukuhamba IBhayibhile Injineli Intambo
# Total Score (Xhosa): 16
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'ingonyama': 3, 'Balekani': 1, 'ukuhamba': 2, 'IBhayibhile': 3, 'Injineli': 2, 'Intambo': 5, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): ibhubesi Baleka ukuhamba IBhayibheli Unjiniyela Intambo
# Total Score (Zulu): 16
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'ibhubesi': 3, 'Baleka': 1, 'ukuhamba': 2, 'IBhayibheli': 3, 'Unjiniyela': 2, 'Intambo': 5, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 12: 'Rewrite appearance fly leave fear.'
#
# Original English Sentence: 'Rewrite appearance fly leave fear.'
#
# Translated Sentence (CILUBA): Fundulula Tshimuenenu Njinji sendemuka
# Total Score (CILUBA): 11
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Fundulula': 3, 'Tshimuenenu': 1, 'Njinji': 3, 'sendemuka': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): réécrire aspect Mouche Partir
# Total Score (FRANCAIS): 11
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'réécrire': 3, 'aspect': 1, 'Mouche': 3, 'Partir': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): ngola bocha ponahalo Fofa Tloha
# Total Score (Sesotho): 11
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'ngola bocha': 3, 'ponahalo': 1, 'Fofa': 3, 'Tloha': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): ngwala gape ponagalo Fofa Tloga
# Total Score (Sepedi): 11
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'ngwala gape': 3, 'ponagalo': 1, 'Fofa': 3, 'Tloga': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): herskryf voorkoms Vlieg Los
# Total Score (Afrikaans): 11
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'herskryf': 3, 'voorkoms': 1, 'Vlieg': 3, 'Los': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): bhala kwakhona inkangeleko Bhabha Hamba
# Total Score (Xhosa): 11
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'bhala kwakhona': 3, 'inkangeleko': 1, 'Bhabha': 3, 'Hamba': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): bhala kabusha ukubukeka Fly Hamba
# Total Score (Zulu): 11
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'bhala kabusha': 3, 'ukubukeka': 1, 'Fly': 3, 'Hamba': 4, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 13: 'Pillow face turn environment assassin advantage begin pulse talk tree giant nail.'
#
# Original English Sentence: 'Pillow face turn environment assassin advantage begin pulse talk tree giant nail.'
#
# Translated Sentence (CILUBA): Musangu tshimfuanyi Kunyungulaka nyungilukilu Mushipianganyi Ditamba Banga Mijilu kuakula mutshi Cileha
# Total Score (CILUBA): 20
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Musangu': 6, 'tshimfuanyi': 2, 'Kunyungulaka': 6, 'nyungilukilu': 1, 'Mushipianganyi': -9, 'Ditamba': 4, 'Banga': 1, 'Mijilu': 1, 'kuakula': 1, 'mutshi': 5, 'Cileha': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Oreiller Visage Tourner environnement assassin avantage Commence Pouls Parler Arbre Géant
# Total Score (FRANCAIS): 20
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Oreiller': 6, 'Visage': 2, 'Tourner': 6, 'environnement': 1, 'assassin': -9, 'avantage': 4, 'Commence': 1, 'Pouls': 1, 'Parler': 1, 'Arbre': 5, 'Géant': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): mosamo Sefahleho Phetla tikoloho mmolai molemo qala Pulse Bua SEFATE Seqhenqha
# Total Score (Sesotho): 20
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'mosamo': 6, 'Sefahleho': 2, 'Phetla': 6, 'tikoloho': 1, 'mmolai': -9, 'molemo': 4, 'qala': 1, 'Pulse': 1, 'Bua': 1, 'SEFATE': 5, 'Seqhenqha': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Mosamelo Sefahlogo Fetoga tikologo mmolai mohola Thoma Pulse ya go otla Bolela MOHLARE Lekgema
# Total Score (Sepedi): 20
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Mosamelo': 6, 'Sefahlogo': 2, 'Fetoga': 6, 'tikologo': 1, 'mmolai': -9, 'mohola': 4, 'Thoma': 1, 'Pulse ya go otla': 1, 'Bolela': 1, 'MOHLARE': 5, 'Lekgema': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Kussing Gesig Draai omgewing sluipmoordenaar voordeel Begin Polsslag Praat BOOM Reus
# Total Score (Afrikaans): 20
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Kussing': 6, 'Gesig': 2, 'Draai': 6, 'omgewing': 1, 'sluipmoordenaar': -9, 'voordeel': 4, 'Begin': 1, 'Polsslag': 1, 'Praat': 1, 'BOOM': 5, 'Reus': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Umqamelo Ubuso Jika okusingqongileyo umbulali inzuzo Qala Ukubetha Intetho UMTHI Isigebenga
# Total Score (Xhosa): 20
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Umqamelo': 6, 'Ubuso': 2, 'Jika': 6, 'okusingqongileyo': 1, 'umbulali': -9, 'inzuzo': 4, 'Qala': 1, 'Ukubetha': 1, 'Intetho': 1, 'UMTHI': 5, 'Isigebenga': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Umcamelo Ubuso Phenduka imvelo umbulali inzuzo Qala I-Pulse Khuluma ISIHLAHLA Umdondoshiya
# Total Score (Zulu): 20
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Umcamelo': 6, 'Ubuso': 2, 'Phenduka': 6, 'imvelo': 1, 'umbulali': -9, 'inzuzo': 4, 'Qala': 1, 'I-Pulse': 1, 'Khuluma': 1, 'ISIHLAHLA': 5, 'Umdondoshiya': 2, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 14: 'World beauty bless eagle sweat love to overcome dust.'
#
# Original English Sentence: 'World beauty bless eagle sweat love to overcome dust.'
#
# Translated Sentence (CILUBA): buloba buimpa kubenesha mukanku tshisululu Dinanga kutshimuna
# Total Score (CILUBA): 20
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'buloba': 2, 'buimpa': 4, 'kubenesha': 1, 'mukanku': 2, 'tshisululu': 2, 'Dinanga': 5, 'kutshimuna': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Monde Beauté benir Aigle Sueur Amour vaincre
# Total Score (FRANCAIS): 20
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Monde': 2, 'Beauté': 4, 'benir': 1, 'Aigle': 2, 'Sueur': 2, 'Amour': 5, 'vaincre': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Lefatshe Botle hlohonolofatsa Ntsu Mofufutso Lerato ho hlola
# Total Score (Sesotho): 20
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Lefatshe': 2, 'Botle': 4, 'hlohonolofatsa': 1, 'Ntsu': 2, 'Mofufutso': 2, 'Lerato': 5, 'ho hlola': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Lefase Bobotse šegofatša Ntšhu Sethitho Lerato go fenya
# Total Score (Sepedi): 20
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Lefase': 2, 'Bobotse': 4, 'šegofatša': 1, 'Ntšhu': 2, 'Sethitho': 2, 'Lerato': 5, 'go fenya': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Wêreld Skoonheid seën Arend Sweet Liefde te oorkom
# Total Score (Afrikaans): 20
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Wêreld': 2, 'Skoonheid': 4, 'seën': 1, 'Arend': 2, 'Sweet': 2, 'Liefde': 5, 'te oorkom': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Ihlabathi Ubuhle sikelela Ukhozi Ukubila Uthando ukoyisa
# Total Score (Xhosa): 20
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Ihlabathi': 2, 'Ubuhle': 4, 'sikelela': 1, 'Ukhozi': 2, 'Ukubila': 2, 'Uthando': 5, 'ukoyisa': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Umhlaba Ubuhle busisa Ukhozi Ajuluke Uthando ukunqoba
# Total Score (Zulu): 20
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Umhlaba': 2, 'Ubuhle': 4, 'busisa': 1, 'Ukhozi': 2, 'Ajuluke': 2, 'Uthando': 5, 'ukunqoba': 4, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 15: 'Body mushrooms 53refuse fifty seven crisis 59shirt spread sadness decision.'
#
# Original English Sentence: 'Body mushrooms 53refuse fifty seven crisis 59shirt spread sadness decision.'
#
# Translated Sentence (CILUBA): mbindi Boowa  makumiatanu muandamuteketa Lukota  kuadija Kubungama
# Total Score (CILUBA): 9
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'mbindi': 5, 'Boowa': 3, '': 0, 'makumiatanu': 0, 'muandamuteketa': 0, 'Lukota': 3, 'kuadija': 4, 'Kubungama': -6}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Corps Champignons  cinquante sept Crise  étaler Tristesse
# Total Score (FRANCAIS): 9
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Corps': 5, 'Champignons': 3, '': 0, 'cinquante': 0, 'sept': 0, 'Crise': 3, 'étaler': 4, 'Tristesse': -6}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): mmele Di-mushroom  mashome a mahlano Supa Mathata  ho jaleha Ho hlomoha
# Total Score (Sesotho): 9
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'mmele': 5, 'Di-mushroom': 3, '': 0, 'mashome a mahlano': 0, 'Supa': 0, 'Mathata': 3, 'ho jaleha': 4, 'Ho hlomoha': -6}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Mmele Di-mushroom  masomehlano tše šupago Tlhakatlhakano  phatlalala Manyami
# Total Score (Sepedi): 9
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Mmele': 5, 'Di-mushroom': 3, '': 0, 'masomehlano': 0, 'tše šupago': 0, 'Tlhakatlhakano': 3, 'phatlalala': 4, 'Manyami': -6}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Liggaam Sampioene  vyftig sewe Krisis  versprei Hartseer
# Total Score (Afrikaans): 9
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Liggaam': 5, 'Sampioene': 3, '': 0, 'vyftig': 0, 'sewe': 0, 'Krisis': 3, 'versprei': 4, 'Hartseer': -6}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Umzimba Amakhowa  Amashumi amahlanu Sixhengxe Ingxaki  usasazeko Usizi
# Total Score (Xhosa): 9
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Umzimba': 5, 'Amakhowa': 3, '': 0, 'Amashumi amahlanu': 0, 'Sixhengxe': 0, 'Ingxaki': 3, 'usasazeko': 4, 'Usizi': -6}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Umzimba Amakhowe  amashumi amahlanu Isikhombisa Inkinga  ukubhebhetheka Ukudabuka
# Total Score (Zulu): 9
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Umzimba': 5, 'Amakhowe': 3, '': 0, 'amashumi amahlanu': 0, 'Isikhombisa': 0, 'Inkinga': 3, 'ukubhebhetheka': 4, 'Ukudabuka': -6}
#
# --------------------------------------------------
#
# Processing sentence 16: 'Freedom to illuminate women sew pond history tuesday kindness hand to walk.'
#
# Original English Sentence: 'Freedom to illuminate women sew pond history tuesday kindness hand to walk.'
#
# Translated Sentence (CILUBA): mudikadila Butoke mukaji Kutela Cilamba mianda Dibiidi Dijingilabuimpabuabakuabu Bianza
# Total Score (CILUBA): 22
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'mudikadila': 1, 'Butoke': 2, 'mukaji': 3, 'Kutela': 1, 'Cilamba': 1, 'mianda': 4, 'Dibiidi': 5, 'Dijingilabuimpabuabakuabu': 4, 'Bianza': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Liberté eclairer Femme coudre Pond Histoire Mardi Bienveillance main
# Total Score (FRANCAIS): 22
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Liberté': 1, 'eclairer': 2, 'Femme': 3, 'coudre': 1, 'Pond': 1, 'Histoire': 4, 'Mardi': 5, 'Bienveillance': 4, 'main': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Tokoloho ho kgantsha Basali roka Letamo Histori labobedi Mosa letsoho
# Total Score (Sesotho): 22
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Tokoloho': 1, 'ho kgantsha': 2, 'Basali': 3, 'roka': 1, 'Letamo': 1, 'Histori': 4, 'labobedi': 5, 'Mosa': 4, 'letsoho': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Tokologo go boneša Basadi rokile Letangwana Histori Labobedi Botho seatla
# Total Score (Sepedi): 22
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Tokologo': 1, 'go boneša': 2, 'Basadi': 3, 'rokile': 1, 'Letangwana': 1, 'Histori': 4, 'Labobedi': 5, 'Botho': 4, 'seatla': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Vryheid te verlig Vroue naaldwerk Dam Geskiedenis Dinsdag Vriendelikheid hand
# Total Score (Afrikaans): 22
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Vryheid': 1, 'te verlig': 2, 'Vroue': 3, 'naaldwerk': 1, 'Dam': 1, 'Geskiedenis': 4, 'Dinsdag': 5, 'Vriendelikheid': 4, 'hand': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Inkululeko ukukhanyisa Abasetyhini thunga Idama Imbali uLwesibini Ububele isandla
# Total Score (Xhosa): 22
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Inkululeko': 1, 'ukukhanyisa': 2, 'Abasetyhini': 3, 'thunga': 1, 'Idama': 1, 'Imbali': 4, 'uLwesibini': 5, 'Ububele': 4, 'isandla': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Inkululeko ukukhanyisa Abesifazane thunga Ichibi Umlando ULwesibili Umusa isandla
# Total Score (Zulu): 22
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Inkululeko': 1, 'ukukhanyisa': 2, 'Abesifazane': 3, 'thunga': 1, 'Ichibi': 1, 'Umlando': 4, 'ULwesibili': 5, 'Umusa': 4, 'isandla': 1, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 17: 'Add slipper bench bourgeois sell to obligate band language.'
#
# Original English Sentence: 'Add slipper bench bourgeois sell to obligate band language.'
#
# Translated Sentence (CILUBA): kusangisha mapapa tshibasa Musoko kupana kukolela Tshilulu
# Total Score (CILUBA): 21
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'kusangisha': 4, 'mapapa': 3, 'tshibasa': 3, 'Musoko': 4, 'kupana': -1, 'kukolela': 4, 'Tshilulu': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): additionner Babouche banc bourgeoise vendre Obliger bande
# Total Score (FRANCAIS): 21
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'additionner': 4, 'Babouche': 3, 'banc': 3, 'bourgeoise': 4, 'vendre': -1, 'Obliger': 4, 'bande': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): eketsa Slipper banka bourgeois rekisa Ho tlama sehlopha
# Total Score (Sesotho): 21
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'eketsa': 4, 'Slipper': 3, 'banka': 3, 'bourgeois': 4, 'rekisa': -1, 'Ho tlama': 4, 'sehlopha': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): hlakanya Slipper ya go thelela panka mo-bourgeois rekiša Go tlama lepanta
# Total Score (Sepedi): 21
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'hlakanya': 4, 'Slipper ya go thelela': 3, 'panka': 3, 'mo-bourgeois': 4, 'rekiša': -1, 'Go tlama': 4, 'lepanta': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): byvoeg Pantoffel bank bourgeois verkoop Om te verplig band
# Total Score (Afrikaans): 21
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'byvoeg': 4, 'Pantoffel': 3, 'bank': 3, 'bourgeois': 4, 'verkoop': -1, 'Om te verplig': 4, 'band': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): yongeza Umtyibilizi isitulo bourgeois thengisa Ukunyanzelisa iqela
# Total Score (Xhosa): 21
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'yongeza': 4, 'Umtyibilizi': 3, 'isitulo': 3, 'bourgeois': 4, 'thengisa': -1, 'Ukunyanzelisa': 4, 'iqela': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): engeza Isiliphu ibhentshi onxiwankulu thengisa Ukuzibophezela ibhande
# Total Score (Zulu): 21
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'engeza': 4, 'Isiliphu': 3, 'ibhentshi': 3, 'onxiwankulu': 4, 'thengisa': -1, 'Ukuzibophezela': 4, 'ibhande': 4, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 18: 'People day wednesday goat pan.'
#
# Original English Sentence: 'People day wednesday goat pan.'
#
# Translated Sentence (CILUBA): Bantu dituku Disatu Mbuji
# Total Score (CILUBA): 16
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Bantu': 4, 'dituku': 2, 'Disatu': 8, 'Mbuji': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): lesgens jour Mercredi Chèvre
# Total Score (FRANCAIS): 16
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'lesgens': 4, 'jour': 2, 'Mercredi': 8, 'Chèvre': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): batho letsatsi Laboraro Phooko
# Total Score (Sesotho): 16
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'batho': 4, 'letsatsi': 2, 'Laboraro': 8, 'Phooko': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): batho letšatši Laboraro Pudi
# Total Score (Sepedi): 16
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'batho': 4, 'letšatši': 2, 'Laboraro': 8, 'Pudi': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): mense dag Woensdag Bok
# Total Score (Afrikaans): 16
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'mense': 4, 'dag': 2, 'Woensdag': 8, 'Bok': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): abantu usuku uLwesithathu Ibhokhwe
# Total Score (Xhosa): 16
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'abantu': 4, 'usuku': 2, 'uLwesithathu': 8, 'Ibhokhwe': 2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): abantu usuku ULwesithathu Imbuzi
# Total Score (Zulu): 16
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'abantu': 4, 'usuku': 2, 'ULwesithathu': 8, 'Imbuzi': 2, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 19: 'Village disappear bamboo investiture thigh habit adultery buttock finger.'
#
# Original English Sentence: 'Village disappear bamboo investiture thigh habit adultery buttock finger.'
#
# Translated Sentence (CILUBA): musoku sama nshiba dibanjidibua Tshibelo Cilamba Masandi Ditaku
# Total Score (CILUBA): 12
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'musoku': 2, 'sama': 4, 'nshiba': 3, 'dibanjidibua': 1, 'Tshibelo': 2, 'Cilamba': 1, 'Masandi': -5, 'Ditaku': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): village Disparaître Bambou investutire Cuissse Habit adultère Fesse
# Total Score (FRANCAIS): 12
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'village': 2, 'Disparaître': 4, 'Bambou': 3, 'investutire': 1, 'Cuissse': 2, 'Habit': 1, 'adultère': -5, 'Fesse': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): motse Nyamela Bamboo Tsetelo Serope tlwaelo bofebe sebono
# Total Score (Sesotho): 12
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'motse': 2, 'Nyamela': 4, 'Bamboo': 3, 'Tsetelo': 1, 'Serope': 2, 'tlwaelo': 1, 'bofebe': -5, 'sebono': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): motse Nyamelela Bamboo Dipeeletšo Serope Setlwaedi bohlotlolo marago
# Total Score (Sepedi): 12
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'motse': 2, 'Nyamelela': 4, 'Bamboo': 3, 'Dipeeletšo': 1, 'Serope': 2, 'Setlwaedi': 1, 'bohlotlolo': -5, 'marago': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): dorpie Verdwyn Bamboes Belegging Bobeen Gewoonte owerspel Boudjie
# Total Score (Afrikaans): 12
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'dorpie': 2, 'Verdwyn': 4, 'Bamboes': 3, 'Belegging': 1, 'Bobeen': 2, 'Gewoonte': 1, 'owerspel': -5, 'Boudjie': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): ilali Inyamalala Ngoqalo Utyalo-mali Ithanga Umkhwa ukukrexeza Impundu
# Total Score (Xhosa): 12
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'ilali': 2, 'Inyamalala': 4, 'Ngoqalo': 3, 'Utyalo-mali': 1, 'Ithanga': 2, 'Umkhwa': 1, 'ukukrexeza': -5, 'Impundu': 4, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): isigodi Inyamalala Uqalo Ukutshala imali Ithanga Umkhuba ukuphinga Isinqe
# Total Score (Zulu): 12
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'isigodi': 2, 'Inyamalala': 4, 'Uqalo': 3, 'Ukutshala imali': 1, 'Ithanga': 2, 'Umkhuba': 1, 'ukuphinga': -5, 'Isinqe': 4, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 20: 'Raise braised stomach sheet metal fisherman live rock to drive judge wet listen to light up.'
#
# Original English Sentence: 'Raise braised stomach sheet metal fisherman live rock to drive judge wet listen to light up.'
#
# Translated Sentence (CILUBA): Dibandishibua Malala Tshifu dilata Mulobi kushikama lubwebwe kuedesha ndumbulula kubola Kunvua  butooka
# Total Score (CILUBA): 30
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Dibandishibua': 3, 'Malala': 3, 'Tshifu': 3, 'dilata': 3, 'Mulobi': 2, 'kushikama': 4, 'lubwebwe': 2, 'kuedesha': 3, 'ndumbulula': 2, 'kubola': 2, 'Kunvua': 1, '': 0, 'butooka': 2}
#
# --------------------------------------------------
#
# ...
#
# Translated Sentence (Sepedi): panka Hlapi Thobalano Morutiwa Manyami Poleiti
# Total Score (Sepedi): 5
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'panka': 3, 'Hlapi': 2, 'Thobalano': 2, 'Morutiwa': 3, 'Manyami': -6, 'Poleiti': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): bank Vis Seks Dissipel Hartseer Plaat
# Total Score (Afrikaans): 5
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'bank': 3, 'Vis': 2, 'Seks': 2, 'Dissipel': 3, 'Hartseer': -6, 'Plaat': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): isitulo Intlanzi Ukwabelana ngesondo Umfundi Usizi Ipleyiti
# Total Score (Xhosa): 5
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'isitulo': 3, 'Intlanzi': 2, 'Ukwabelana ngesondo': 2, 'Umfundi': 3, 'Usizi': -6, 'Ipleyiti': 1, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): ibhentshi Inhlanzi Ucansi Umfundi Ukudabuka Ipuleti
# Total Score (Zulu): 5
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'ibhentshi': 3, 'Inhlanzi': 2, 'Ucansi': 2, 'Umfundi': 3, 'Ukudabuka': -6, 'Ipuleti': 1, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 45: 'Cassava self-centered weed bag would win return branch well supplication.'
#
# Original English Sentence: 'Cassava self-centered weed bag would win return branch well supplication.'
#
# Translated Sentence (CILUBA): Tshiomba badisue kuihila mufuku Kucimuna Alukila Ditamba Tshina
# Total Score (CILUBA): 22
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Tshiomba': 1, 'badisue': 2, 'kuihila': 4, 'mufuku': 4, 'Kucimuna': 3, 'Alukila': 1, 'Ditamba': 4, 'Tshina': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): manioc Egoïste sarcler Sac vincrait Retourne branche Puit
# Total Score (FRANCAIS): 22
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'manioc': 1, 'Egoïste': 2, 'sarcler': 4, 'Sac': 4, 'vincrait': 3, 'Retourne': 1, 'branche': 4, 'Puit': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): cassava Boiketsi ba boithati lehola Mokotla e ne e tla hlola Kgutla lekala Hantle
# Total Score (Sesotho): 22
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'cassava': 1, 'Boiketsi ba boithati': 2, 'lehola': 4, 'Mokotla': 4, 'e ne e tla hlola': 3, 'Kgutla': 1, 'lekala': 4, 'Hantle': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): cassava Go itšeela godimo ngwang Mokotla e be e tla fenya Boa lekala Gabotse
# Total Score (Sepedi): 22
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'cassava': 1, 'Go itšeela godimo': 2, 'ngwang': 4, 'Mokotla': 4, 'e be e tla fenya': 3, 'Boa': 1, 'lekala': 4, 'Gabotse': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): maniok Selfgesentreerd onkruid Sak sou wen Keer terug tak Wel
# Total Score (Afrikaans): 22
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'maniok': 1, 'Selfgesentreerd': 2, 'onkruid': 4, 'Sak': 4, 'sou wen': 3, 'Keer terug': 1, 'tak': 4, 'Wel': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): icassava Ukuzicingela ukhula Ibhegi ingaphumelela Buyela isebe Kulungile
# Total Score (Xhosa): 22
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'icassava': 1, 'Ukuzicingela': 2, 'ukhula': 4, 'Ibhegi': 4, 'ingaphumelela': 3, 'Buyela': 1, 'isebe': 4, 'Kulungile': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): umdumbula Ukuzicabangela yena yedwa ukhula Isikhwama uzowina Buyela igatsha Hhayi-ke
# Total Score (Zulu): 22
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'umdumbula': 1, 'Ukuzicabangela yena yedwa': 2, 'ukhula': 4, 'Isikhwama': 4, 'uzowina': 3, 'Buyela': 1, 'igatsha': 4, 'Hhayi-ke': 3, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 46: 'Chicken 31give vein agame choose mouth system plate blood.'
#
# Original English Sentence: 'Chicken 31give vein agame choose mouth system plate blood.'
#
# Translated Sentence (CILUBA): nzolu  mujilu Mumbembela kusungula Mukana bwezedi Dilongo
# Total Score (CILUBA): 13
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'nzolu': 1, '': 0, 'mujilu': 2, 'Mumbembela': 2, 'kusungula': 1, 'Mukana': 3, 'bwezedi': 3, 'Dilongo': 1}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): poule  Veine Agame choisir Bouche Système Assiette
# Total Score (FRANCAIS): 13
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'poule': 1, '': 0, 'Veine': 2, 'Agame': 2, 'choisir': 1, 'Bouche': 3, 'Système': 3, 'Assiette': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): khoho  Mothapo Agame khetha Molomo Tsamaiso Letlapa
# Total Score (Sesotho): 13
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'khoho': 1, '': 0, 'Mothapo': 2, 'Agame': 2, 'khetha': 1, 'Molomo': 3, 'Tsamaiso': 3, 'Letlapa': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): nama ya kgogo  Mothapo Agame kgetha Molomo Tshepedišo Poleiti
# Total Score (Sepedi): 13
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'nama ya kgogo': 1, '': 0, 'Mothapo': 2, 'Agame': 2, 'kgetha': 1, 'Molomo': 3, 'Tshepedišo': 3, 'Poleiti': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): hoender  Aar Agame kies Mond Stelsel Plaat
# Total Score (Afrikaans): 13
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'hoender': 1, '': 0, 'Aar': 2, 'Agame': 2, 'kies': 1, 'Mond': 3, 'Stelsel': 3, 'Plaat': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): inkukhu  Umthambo Agame khetha Umlomo Inkqubo Ipleyiti
# Total Score (Xhosa): 13
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'inkukhu': 1, '': 0, 'Umthambo': 2, 'Agame': 2, 'khetha': 1, 'Umlomo': 3, 'Inkqubo': 3, 'Ipleyiti': 1}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): inyama yenkukhu  Umthambo Agame khetha Umlomo Uhlelo Ipuleti
# Total Score (Zulu): 13
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'inyama yenkukhu': 1, '': 0, 'Umthambo': 2, 'Agame': 2, 'khetha': 1, 'Umlomo': 3, 'Uhlelo': 3, 'Ipuleti': 1}
#
# --------------------------------------------------
#
# Processing sentence 47: 'Patience water pants thirty five mulombodi.'
#
# Original English Sentence: 'Patience water pants thirty five mulombodi.'
#
# Translated Sentence (CILUBA): lutulu Mayi muhanu makumiasatu itanu
# Total Score (CILUBA): 7
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'lutulu': 1, 'Mayi': 3, 'muhanu': 3, 'makumiasatu': 0, 'itanu': 0, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): patience Eau Pantalon trente cinq
# Total Score (FRANCAIS): 7
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'patience': 1, 'Eau': 3, 'Pantalon': 3, 'trente': 0, 'cinq': 0, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): mamello Metsi Borikhoe mashome a mararo hlano
# Total Score (Sesotho): 7
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'mamello': 1, 'Metsi': 3, 'Borikhoe': 3, 'mashome a mararo': 0, 'hlano': 0, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): boiketlo Meetse Marokgwana masometharo hlano
# Total Score (Sepedi): 7
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'boiketlo': 1, 'Meetse': 3, 'Marokgwana': 3, 'masometharo': 0, 'hlano': 0, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): geduld Water Broek dertig vyf
# Total Score (Afrikaans): 7
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'geduld': 1, 'Water': 3, 'Broek': 3, 'dertig': 0, 'vyf': 0, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): umonde Amanzi Iibhulukhwe Amashumi amathathu Ntlanu
# Total Score (Xhosa): 7
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'umonde': 1, 'Amanzi': 3, 'Iibhulukhwe': 3, 'Amashumi amathathu': 0, 'Ntlanu': 0, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): ukubekezela Amanzi Amabhulukwe amashumi amathathu amahlanu
# Total Score (Zulu): 7
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'ukubekezela': 1, 'Amanzi': 3, 'Amabhulukwe': 3, 'amashumi amathathu': 0, 'amahlanu': 0, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 48: 'Iron to remove four activity tear 39come suffers muscle game.'
#
# Original English Sentence: 'Iron to remove four activity tear 39come suffers muscle game.'
#
# Translated Sentence (CILUBA): tshiamua Kumusha inayi Disuminyina disoso  Kenga Musunyi
# Total Score (CILUBA): 8
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'tshiamua': 2, 'Kumusha': 1, 'inayi': 0, 'Disuminyina': 3, 'disoso': -4, '': 0, 'Kenga': 3, 'Musunyi': 3}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Feràrepasser enlever quatre activité Déchirure  souffres Muscle
# Total Score (FRANCAIS): 8
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Feràrepasser': 2, 'enlever': 1, 'quatre': 0, 'activité': 3, 'Déchirure': -4, '': 0, 'souffres': 3, 'Muscle': 3}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): tshepe ho tlosa nne mosebetsi Keledi  mahlomola Mosifa
# Total Score (Sesotho): 8
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'tshepe': 2, 'ho tlosa': 1, 'nne': 0, 'mosebetsi': 3, 'Keledi': -4, '': 0, 'mahlomola': 3, 'Mosifa': 3}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Aene go tloša tše nne mošomo Gagola  o a tlaišega Mošifa
# Total Score (Sepedi): 8
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Aene': 2, 'go tloša': 1, 'tše nne': 0, 'mošomo': 3, 'Gagola': -4, '': 0, 'o a tlaišega': 3, 'Mošifa': 3}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Yster te verwyder vier aktiwiteit Skeur  ly Spier
# Total Score (Afrikaans): 8
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Yster': 2, 'te verwyder': 1, 'vier': 0, 'aktiwiteit': 3, 'Skeur': -4, '': 0, 'ly': 3, 'Spier': 3}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Intsimbi ukususa ezine umsebenzi Iinyembezi  uyahlupheka Izihlunu
# Total Score (Xhosa): 8
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Intsimbi': 2, 'ukususa': 1, 'ezine': 0, 'umsebenzi': 3, 'Iinyembezi': -4, '': 0, 'uyahlupheka': 3, 'Izihlunu': 3}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Insimbi ukususa ezine umsebenzi Izinyembezi  uyahlupheka Imisipha
# Total Score (Zulu): 8
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Insimbi': 2, 'ukususa': 1, 'ezine': 0, 'umsebenzi': 3, 'Izinyembezi': -4, '': 0, 'uyahlupheka': 3, 'Imisipha': 3}
#
# --------------------------------------------------
#
# Processing sentence 49: 'Arm poverty rearrange prepare hope tarpaulin answer.'
#
# Original English Sentence: 'Arm poverty rearrange prepare hope tarpaulin answer.'
#
# Translated Sentence (CILUBA): diboko Bulanda Akajulula kulongolola kutekemena: Nteta
# Total Score (CILUBA): 19
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'diboko': 2, 'Bulanda': 5, 'Akajulula': 2, 'kulongolola': 2, 'kutekemena:': 5, 'Nteta': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Bras Pauvreté réarranger Préparer Espérance Bâche
# Total Score (FRANCAIS): 19
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Bras': 2, 'Pauvreté': 5, 'réarranger': 2, 'Préparer': 2, 'Espérance': 5, 'Bâche': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): Letsoho Bofutsana hlophisa bocha Lokisetsa tshepo Tarpaulin
# Total Score (Sesotho): 19
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'Letsoho': 2, 'Bofutsana': 5, 'hlophisa bocha': 2, 'Lokisetsa': 2, 'tshepo': 5, 'Tarpaulin': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Letsogo Bodiidi beakanya gape Beakanya Kholofelo Tarpaulin ya go dira dilo
# Total Score (Sepedi): 19
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Letsogo': 2, 'Bodiidi': 5, 'beakanya gape': 2, 'Beakanya': 2, 'Kholofelo': 5, 'Tarpaulin ya go dira dilo': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Arm Armoede herrangskik Berei voor Hoop Seil
# Total Score (Afrikaans): 19
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Arm': 2, 'Armoede': 5, 'herrangskik': 2, 'Berei voor': 2, 'Hoop': 5, 'Seil': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Ingalo Ubuhlwempu cwangcisa ngokutsha Lungiselela Ithemba Iseyile
# Total Score (Xhosa): 19
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Ingalo': 2, 'Ubuhlwempu': 5, 'cwangcisa ngokutsha': 2, 'Lungiselela': 2, 'Ithemba': 5, 'Iseyile': 3, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Ingalo Ubumpofu hlela kabusha Lungiselela Themba Iseyili
# Total Score (Zulu): 19
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Ingalo': 2, 'Ubumpofu': 5, 'hlela kabusha': 2, 'Lungiselela': 2, 'Themba': 5, 'Iseyili': 3, '': 0}
#
# --------------------------------------------------
#
# Processing sentence 50: 'Blood river jaw camp grass foot thumbtack regret swim.'
#
# Original English Sentence: 'Blood river jaw camp grass foot thumbtack regret swim.'
#
# Translated Sentence (CILUBA): Mashi musulu Lubanga Tshitudilu tshisosa Dikasa Bihu dinyingalala
# Total Score (CILUBA): 16
# Sentiment (CILUBA): Positive
# Word Scores (CILUBA): {'Mashi': 3, 'musulu': 2, 'Lubanga': 4, 'Tshitudilu': 1, 'tshisosa': 3, 'Dikasa': 3, 'Bihu': 2, 'dinyingalala': -2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (FRANCAIS): Sang Fleuve Machoire camp Herbe pied Punaise Regret
# Total Score (FRANCAIS): 16
# Sentiment (FRANCAIS): Positive
# Word Scores (FRANCAIS): {'Sang': 3, 'Fleuve': 2, 'Machoire': 4, 'camp': 1, 'Herbe': 3, 'pied': 3, 'Punaise': 2, 'Regret': -2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sesotho): madi Noka Mohlahare kampo Joang leoto Thumbtack Maikutlo
# Total Score (Sesotho): 16
# Sentiment (Sesotho): Positive
# Word Scores (Sesotho): {'madi': 3, 'Noka': 2, 'Mohlahare': 4, 'kampo': 1, 'Joang': 3, 'leoto': 3, 'Thumbtack': 2, 'Maikutlo': -2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Sepedi): Madi Noka Mohlagare kampa Bjang leoto Go swara ka monwana o mogolo Maswabi
# Total Score (Sepedi): 16
# Sentiment (Sepedi): Positive
# Word Scores (Sepedi): {'Madi': 3, 'Noka': 2, 'Mohlagare': 4, 'kampa': 1, 'Bjang': 3, 'leoto': 3, 'Go swara ka monwana o mogolo': 2, 'Maswabi': -2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Afrikaans): Bloed Rivier Kaakbeen kamp Gras voet Duimstok Berou
# Total Score (Afrikaans): 16
# Sentiment (Afrikaans): Positive
# Word Scores (Afrikaans): {'Bloed': 3, 'Rivier': 2, 'Kaakbeen': 4, 'kamp': 1, 'Gras': 3, 'voet': 3, 'Duimstok': 2, 'Berou': -2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Xhosa): Igazi Umlambo Umhlathi inkampu Ingca unyawo I-Thumbtack Ukuzisola
# Total Score (Xhosa): 16
# Sentiment (Xhosa): Positive
# Word Scores (Xhosa): {'Igazi': 3, 'Umlambo': 2, 'Umhlathi': 4, 'inkampu': 1, 'Ingca': 3, 'unyawo': 3, 'I-Thumbtack': 2, 'Ukuzisola': -2, '': 0}
#
# --------------------------------------------------
#
# Translated Sentence (Zulu): Igazi Umfula Umhlathi ikamu Utshani unyawo I-Thumbtack Ukuzisola
# Total Score (Zulu): 16
# Sentiment (Zulu): Positive
# Word Scores (Zulu): {'Igazi': 3, 'Umfula': 2, 'Umhlathi': 4, 'ikamu': 1, 'Utshani': 3, 'unyawo': 3, 'I-Thumbtack': 2, 'Ukuzisola': -2, '': 0}
#
# --------------------------------------------------
